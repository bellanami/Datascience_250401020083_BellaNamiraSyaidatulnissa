# %% [markdown]
# **Nama:** Bella Namira Syaidatulnissa
# <br>**NIM:** 250401020083
# <br>**Kelas:** 250401020083

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# SEL 2: Variabel & tipe data
nama     = "Bella Namira Syaidatulnissa"
angkatan = 2025
ipk = 3.84
aktif = True

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
    print(f"  {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Bella Namira Syaidatulnissa", "Informatika", 2025)
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
# Nama : Bella Namira Syaidatulnissa
# Angkatan: 2025
# IPK : 3.84
# Aktif : True
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. GitHub
# Hai! Saya Bella Namira Syaidatulnissa dari Informatika, angkatan 2025.

# %% [markdown]
# ## Kesimpulan Pembelajaran
#
# Setelah mengikuti pembelajaran ini, saya telah menguasai beberapa dasar penting dalam Python untuk Data Science:
#
# *   **Output Sederhana:** Memahami penggunaan fungsi `print()` untuk menampilkan informasi.
# *   **Variabel dan Tipe Data:** Mengenal dan menerapkan berbagai tipe data dasar seperti `string`, `integer`, `float`, dan `boolean`.
# *   **List dan Perulangan:** Mampu bekerja dengan struktur data `list` dan melakukan iterasi menggunakan `for` loop, termasuk `enumerate()`.
# *   **Fungsi Python:** Dapat membuat dan memanfaatkan fungsi (`def`) untuk modularitas dan reusable code.
