# %% [markdown]
# **Nama:** Bella Namira Syaidatulnissa
# <br>**NIM:** 250401020083
# <br>**Kelas:** **IF405**

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
produk = ['Roti', 'Selai', 'Susu', 'Sereal', 'Telur',
          'Keju', 'Kopi', 'Gula', 'Teh', 'Mentega']

# Buat 50 transaksi, tiap transaksi berisi 2-5 produk
transaksi = []
for _ in range(50):
    n_item = np.random.randint(2, 6)
    transaksi.append(list(np.random.choice(produk, n_item, replace=False)))

# Suntikkan pola: Roti sering bersama Selai
for i in range(0, 20):
    if 'Roti' in transaksi[i] and 'Selai' not in transaksi[i]:
        transaksi[i].append('Selai')

print('Contoh transaksi:', transaksi[:3])
print('Jumlah transaksi:', len(transaksi))
# Out:
# Contoh transaksi: [[np.str_('Keju'), np.str_('Roti'), np.str_('Mentega'), np.str_('Kopi'), 'Selai'], [np.str_('Roti'), np.str_('Kopi'), np.str_('Teh'), np.str_('Selai'), np.str_('Mentega')], [np.str_('Kopi'), np.str_('Susu'), np.str_('Teh')]]
# Jumlah transaksi: 50

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transaksi).transform(transaksi)
df = pd.DataFrame(te_ary, columns=te.columns_)
print(df.head())
# Out:
#     Gula   Keju   Kopi  Mentega   Roti  Selai  Sereal   Susu    Teh  Telur
# 0  False   True   True     True   True   True   False  False  False  False
# 1  False  False   True     True   True   True   False  False   True  False
# 2  False  False   True    False  False  False   False   True   True  False
# 3  False   True  False    False  False   True   False  False   True   True
# 4   True   True  False     True  False  False   False   True  False  False

# %%
from mlxtend.frequent_patterns import apriori
for ms in [0.05, 0.1, 0.2]:
    freq = apriori(df, min_support=ms, use_colnames=True)
    print(f'min_support={ms}: {len(freq)} itemset ditemukan')

# Gunakan min_support yang menghasilkan jumlah itemset wajar (tidak 0, tidak ratusan)
freq_items = apriori(df, min_support=0.1, use_colnames=True)
freq_items = freq_items.sort_values('support', ascending=False)
print(freq_items.head(10))
# Out:
# min_support=0.05: 74 itemset ditemukan
# min_support=0.1: 44 itemset ditemukan
# min_support=0.2: 13 itemset ditemukan
#     support      itemsets
# 5      0.52       (Selai)
# 8      0.46         (Teh)
# 3      0.42     (Mentega)
# 9      0.36       (Telur)
# 1      0.34        (Keju)
# 0      0.32        (Gula)
# 2      0.32        (Kopi)
# 4      0.32        (Roti)
# 7      0.32        (Susu)
# 36     0.24  (Teh, Selai)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
from mlxtend.frequent_patterns import association_rules
rules = association_rules(freq_items, metric='confidence',
min_threshold=0.5)
rules = rules[rules['lift'] > 1].sort_values('lift', ascending=False)
print(rules[['antecedents', 'consequents',
'support', 'confidence', 'lift']].head(10))
# Interpretasikan dalam sel Markdown:
# Aturan mana yang paling kuat (Lift tertinggi)?
# Apakah masuk akal secara bisnis (mis. Roti -> Selai)?
# Out:
#          antecedents consequents  support  confidence      lift
# 9        (Teh, Keju)     (Telur)     0.12    0.857143  2.380952
# 14  (Mentega, Selai)      (Kopi)     0.10    0.625000  1.953125
# 12      (Roti, Gula)     (Selai)     0.10    1.000000  1.923077
# 7           (Sereal)   (Mentega)     0.14    0.777778  1.851852
# 8       (Teh, Telur)      (Keju)     0.12    0.600000  1.764706
# 15     (Selai, Kopi)   (Mentega)     0.10    0.714286  1.700680
# 10     (Telur, Keju)       (Teh)     0.12    0.750000  1.630435
# 11     (Selai, Gula)      (Roti)     0.10    0.500000  1.562500
# 13   (Mentega, Kopi)     (Selai)     0.10    0.714286  1.373626
# 1             (Roti)     (Selai)     0.22    0.687500  1.322115
# ...

# %% [markdown]
# Berdasarkan hasil `association_rules` yang diurutkan berdasarkan `lift` tertinggi:
#
# 1.  **Aturan mana yang paling kuat (Lift tertinggi)?**
#     Aturan dengan `lift` tertinggi adalah `(Teh, Keju) -> (Telur)` dengan nilai `lift` sekitar **2.38**. Ini berarti bahwa pelanggan yang membeli Teh dan Keju cenderung **2.38 kali lebih mungkin** untuk membeli Telur dibandingkan dengan pelanggan pada umumnya.
#
# 2.  **Apakah masuk akal secara bisnis (mis. Roti -> Selai)?**
#     *   **`(Teh, Keju) -> (Telur)` (Lift 2.38):** Kombinasi Teh, Keju, dan Telur mungkin tidak langsung terlihat sebagai pembelian yang sangat sering bersamaan dalam konteks sarapan atau makanan ringan tertentu, tetapi `lift` yang tinggi menunjukkan adanya korelasi kuat dalam dataset ini. Mungkin ini memperlihatkan kebiasaan belanja spesifik dari segmen pelanggan tertentu atau promosi yang berlaku.
#
#     *   **`(Roti) -> (Selai)` (Lift 1.32):** Aturan ini memiliki `lift` sekitar **1.32**. Ini sangat masuk akal secara bisnis. Roti dan Selai adalah produk komplementer yang sering dikonsumsi bersama, terutama untuk sarapan atau makanan ringan. `Lift` di atas 1 mengindikasikan bahwa pembelian Roti dan Selai terjadi bersamaan lebih sering daripada yang diharapkan secara acak, yang mendukung intuisi bisnis.

# %%
from sklearn.metrics.pairwise import cosine_similarity
katalog = pd.DataFrame({
'produk': produk,
'kategori': ['Bakery','Bakery','Dairy','Bakery','Dairy',
'Dairy','Minuman','Bumbu','Minuman','Dairy']
})
fitur = pd.get_dummies(katalog['kategori'])
sim_matrix = cosine_similarity(fitur)
def rekomendasi_serupa(nama_produk, top_n=3):
    idx = katalog.index[katalog['produk'] == nama_produk][0]
    skor = list(enumerate(sim_matrix[idx]))
    skor = sorted(skor, key=lambda x: x[1], reverse=True)
    skor = [s for s in skor if s[0] != idx][:top_n]
    return katalog.iloc[[i for i, _ in skor]]['produk'].tolist()
print('Mirip dengan Roti:', rekomendasi_serupa('Roti'))
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
produk_target = 'Roti'
# Dari association rules: cari consequents dari aturan yang antecedent-nya mengandung
produk_target
rules_terkait = rules[rules['antecedents'].apply(
lambda x: produk_target in x)]
print('Rekomendasi dari Association Rules:')
print(rules_terkait[['consequents', 'lift']].head())
print('Rekomendasi dari Content-Based:', rekomendasi_serupa(produk_target))
# Diskusikan: apakah kedua pendekatan memberi rekomendasi yang konsisten?
# Kapan sebaiknya menggunakan salah satu, atau menggabungkan keduanya (hybrid)?
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %% [markdown]
# 1. Apakah kedua pendekatan memberi rekomendasi yang konsisten?
#
# Untuk `produk_target = 'Roti'`:
#
# *   **Association Rules:** `(Selai)`
# *   **Content-Based:** `['Selai', 'Sereal', 'Susu']`
#
# Kedua pendekatan sebagian konsisten. Keduanya merekomendasikan 'Selai' (logis karena pola dan kategori serupa). Namun, Content-Based juga menyertakan 'Sereal' dan 'Susu' berdasarkan kategori.
#
# 2. Kapan sebaiknya menggunakan salah satu, atau menggabungkan keduanya (hybrid)?
#
# *   Association Rules: Untuk hubungan antar produk yang sering dibeli bersama. Unggul dalam pola tak terduga dan data transaksi besar.
#
# *   Content-Based: Untuk produk yang serupa secara intrinsik (berdasarkan atribut). Berguna untuk produk baru (cold start) dan rekomendasi kontekstual.
#
# *   Hybrid Approach: Menggabungkan keduanya untuk rekomendasi lebih komprehensif dan akurat. Ini mengatasi kelemahan masing-masing, menghasilkan personalisasi lebih baik dengan mempertimbangkan item dan perilaku.

# %% [markdown]
# Berikut adalah kesimpulan singkat dari analisis yang telah saya lakukan:
#
# *   **Pembelajaran yang Didapat:** Dari proyek ini, saya mempelajari bagaimana menerapkan algoritma Apriori untuk menemukan frequent itemsets dan association rules dari data transaksi, serta bagaimana menggunakan metode content-based untuk rekomendasi produk serupa berdasarkan atribut kategori. Saya juga memahami pentingnya metrik `support`, `confidence`, dan `lift` dalam mengevaluasi kekuatan suatu aturan asosiasi.
#
# *   **Temuan Utama:** Saya menemukan bahwa aturan asosiasi dengan `lift` tertinggi adalah `(Teh, Keju) -> (Telur)`, yang menunjukkan korelasi kuat meskipun tidak selalu intuitif secara bisnis. Di sisi lain, rekomendasi `(Roti) -> (Selai)` memiliki `lift` yang lebih rendah tetapi sangat relevan secara bisnis, mendukung intuisi umum mengenai produk komplementer. Pendekatan content-based juga berhasil mengidentifikasi produk serupa berdasarkan kategori, seperti 'Sereal' dan 'Susu' yang mirip dengan 'Roti' dari kategori yang sama.
#
# *   **Keterbatasan dan Pertanyaan:** Keterbatasan utama dari analisis ini adalah ukuran dataset yang relatif kecil (hanya 50 transaksi), yang mungkin tidak sepenuhnya merepresentasikan pola belanja konsumen yang lebih kompleks. Selain itu, dataset sintetis mungkin tidak mencerminkan noise atau anomali yang sering ditemukan pada data riil. Pertanyaan yang muncul adalah bagaimana cara mengintegrasikan kedua pendekatan (asosiasi dan content-based) secara lebih canggih untuk sistem rekomendasi _hybrid_ yang lebih personal dan dinamis, serta bagaimana kinerja model ini akan berubah pada dataset dengan skala yang jauh lebih besar dan beragam.
