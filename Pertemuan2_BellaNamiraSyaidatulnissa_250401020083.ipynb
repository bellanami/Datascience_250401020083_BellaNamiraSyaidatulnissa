# %% [markdown]
# **Nama:** Bella Namira Syaidatulnissa
# <br>**NIM:** 250401020083
# <br>**Kelas:** IF405

# %%
# 4. Impor library yang dibutuhkan [cite: 312, 321]
import pandas as pd
import numpy as np

# 5. Muat dataset Titanic dari URL GitHub [cite: 322, 323]
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Q1: Berapa jumlah baris dan kolom? Kolom apa saja yang tersedia? [cite: 326, 327]
print("--- Q1 ---")
print(f"Jumlah baris dan kolom: {df.shape}") # [cite: 230]
print(f"Daftar kolom: {df.columns.tolist()}\n") # [cite: 234]
# Out:
# --- Q1 ---
# Jumlah baris dan kolom: (891, 12)
# Daftar kolom: ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
# Q2: Kolom mana yang memiliki missing values? Jumlah dan proporsinya? [cite: 327, 328]
print("--- Q2 ---")
missing_data = df.isnull().sum()
total_rows = len(df)
missing_info = pd.DataFrame({
    'Jumlah Missing': missing_data,
    'Proporsi (%)': (missing_data / total_rows) * 100
})
print(missing_info[missing_info['Jumlah Missing'] > 0], "\n")
# Out:
# --- Q2 ---
#           Jumlah Missing  Proporsi (%)
# Age                  177     19.865320
# Cabin                687     77.104377
# Embarked               2      0.224467

# %%
# Q3: Berapa persen penumpang yang selamat (Survived=1)? [cite: 328, 329]
print("--- Q3 ---")
# Menggunakan Pandas mean() karena kolom Survived berisi 0 dan 1 [cite: 289]
percent_survived = df['Survived'].mean() * 100
print(f"Persentase penumpang selamat: {percent_survived:.2f}%\n")
# Out:
# --- Q3 ---
# Persentase penumpang selamat: 38.38%

# %%
# Q4: Filter penumpang wanita dari kelas 1 (Pclass=1). Jumlah dan rata-rata usia? [cite: 329, 330]
print("--- Q4 ---")
# Menggunakan Boolean Indexing dengan kondisi ganda [cite: 274, 275]
wanita_kelas1 = df[(df['Sex'] == 'female') & (df['Pclass'] == 1)]
print(f"Jumlah penumpang wanita kelas 1: {len(wanita_kelas1)}")
print(f"Rata-rata usia: {wanita_kelas1['Age'].mean():.2f} tahun\n")
# Out:
# --- Q4 ---
# Jumlah penumpang wanita kelas 1: 94
# Rata-rata usia: 34.61 tahun

# %%
# Q5: Hitung tingkat keselamatan (mean Survived) per kelas penumpang. [cite: 330, 331]
print("--- Q5 ---")
# Menggunakan groupby dan agregasi mean [cite: 281, 289]
survival_by_class = df.groupby('Pclass')['Survived'].mean()
print(survival_by_class)
print(f"Kelas dengan tingkat keselamatan tertinggi: Kelas {survival_by_class.idxmax()}\n")
# Out:
# --- Q5 ---
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64
# Kelas dengan tingkat keselamatan tertinggi: Kelas 1

# %%
# Q6: Analisis tambahan: Hubungan antara jenis kelamin dan keselamatan [cite: 331]
print("--- Q6 ---")
# Analisis tambahan menggunakan groupby multi-kolom [cite: 304, 305]
analisis_gender = df.groupby('Sex')['Survived'].mean()
print("Tingkat keselamatan berdasarkan jenis kelamin:")
print(analisis_gender)
# Out:
# --- Q6 ---
# Tingkat keselamatan berdasarkan jenis kelamin:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %% [markdown]
# ## Pelajaran dari Analisis Dataset Titanic
#
# Berdasarkan poin-poin kesimpulan di atas, saya dapat belajar beberapa hal penting:
#
# 1.  **Pentingnya Kualitas Data:** Adanya *missing values* yang signifikan menunjukkan pentingnya langkah pembersihan data (`data cleaning`) sebelum analisis lebih lanjut, terutama untuk kolom seperti 'Cabin' yang hampir 77% datanya hilang.
# 2.  **Faktor Sosial Ekonomi Berdampak pada Survival:** Tingkat keselamatan yang jauh lebih tinggi pada penumpang kelas 1 dibandingkan kelas 3 menegaskan bahwa status sosial dan ekonomi (yang direpresentasikan oleh kelas tiket) memainkan peran krusial dalam peluang bertahan hidup. Hal ini mungkin berkaitan dengan akses ke sekoci atau lokasi kabin.
# 3.  **Prioritas Keselamatan Berdasarkan Gender:** Perbedaan besar dalam tingkat keselamatan antara wanita dan pria (74.20% vs 18.89%) secara jelas menunjukkan bahwa ada kebijakan prioritas "wanita dan anak-anak dahulu" selama proses evakuasi. Ini adalah temuan historis yang kuat dari tragedi Titanic.
# 4.  **Analisis Data Memberikan Wawasan Nyata:** Dengan menganalisis data, kita bisa menggali cerita dan pola di balik angka-angka, seperti dampak keputusan darurat, kondisi sosial, dan demografi pada peristiwa nyata.
